# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False # 用来正常显示负号

# %%
A = np.array([[11, -6, 4, -10, -4],
             [-3, 5, -2, 4, 1],
             [-8, 12, -3, 12, 4],
             [1, 6, -2, 3, -1],
             [8, -18, 8, -14, -1]])

print(A)
# Out:
# [[ 11  -6   4 -10  -4]
#  [ -3   5  -2   4   1]
#  [ -8  12  -3  12   4]
#  [  1   6  -2   3  -1]
#  [  8 -18   8 -14  -1]]

# %%
x1 = [ 1.0000000000000000,      -0.33333333332825821,      -0.99999999998477695,        1.5225984097683488E-011,  0.99999999996954880  ]
x1 = np.array(x1)
x2 = np.matmul(A, x1.T)
print(x2 / x1)
# Out:
# [5.         5.         5.         5.00026714 5.        ]

# %%
eigenvalue, featurevector = np.linalg.eig(A)

print("特征值：", eigenvalue)
print("特征向量: \n", featurevector)
# print(np.matmul(A, featurevector))
# Out:
# 特征值： [5. 3. 1. 1. 5.]
# 特征向量:
#  [[ 5.66946710e-01  3.24442842e-01 -7.48799395e-02 -3.77333376e-01
#   -7.79437420e-01]
#  [-1.88982237e-01 -1.62221421e-01  2.28473300e-01  1.00220873e-01
#    9.13259870e-02]
#  [-5.66946710e-01 -6.48885685e-01 -3.07186720e-01  5.54225007e-01
#    2.73977961e-01]
#  [ 1.01782517e-16 -1.62221421e-01 -6.10539960e-01  7.66707578e-02
#   -5.05459459e-01]
#  [ 5.66946710e-01  6.48885685e-01  6.89253380e-01 -7.31116637e-01
#    2.31481498e-01]]

# %%
-0.69215237, 0.18310814, 0.54932441, -0.14282795, -0.40649646, -0.69215237, 0.18310814, 0.54932441, -0.14282795, -0.40649646
# Out:
# (-0.69215237,
#  0.18310814,
#  0.54932441,
#  -0.14282795,
#  -0.40649646,
#  -0.69215237,
#  0.18310814,
#  0.54932441,
#  -0.14282795,
#  -0.40649646)

# %%
S = [906.000000000000000000 ,
   0.561811229147843871 ,
   0.065676243478349786 ,
   0.016881420002176149 ,
   0.005037421220203981 ,
   0.001620889596568021 ,
   0.000547802293674375 ,
   0.000190448211001658 ,
   0.000067234462716845 ,
   0.000023934909686660 ,
   0.000008560452668899 ,
   0.000003069893020370 ,
   0.000001102627270002 ,
   0.000000396401927451 ,
   0.000000142587626883 ,
   0.000000051306308131 ,
   0.000000018464825438 ,
   0.000000006646161629 ,
   0.000000002392364356 ,
   0.000000000861196351 ,
   0.000000000310018847 ,
   0.000000000111604228 ,
   0.000000000040176970 ,
   0.000000000014463590 ,
   0.000000000005206867 ,
   0.000000000001874466 ,
   0.000000000000674807 ,
   0.000000000000242930 ,
   0.000000000000087455 ,
   0.000000000000031484 ,
   0.000000000000011334 ,
   0.000000000000004080 ,
   0.000000000000001469 ,
   0.000000000000000529 ,
   0.000000000000000190]
S = np.array(S)

# %%
step = len(S)

x = np.arange(step)
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x[1:], S[1:], label='非上三角元素平方和')
ax.grid()
ax.set_xlabel('迭代次数', fontsize=15)
ax.legend(fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.set_title('非上三角元素平方和随迭代次数的变化', fontsize=15)
plt.show()
# plt.savefig('S.png')

# %%
A11 = [11.000000000000000000 ,
   6.467181467181466914 ,
   5.559149638046363862 ,
   5.280427244380346607 ,
   5.155638691367900428 ,
   5.089976274406263101 ,
   5.052960191464137552 ,
   5.031444613761665074 ,
   5.018754739912992591 ,
   5.011213959435272258 ,
   5.006714666447653173 ,
   0.999999999999999445 ,
   0.999999999999999445]

A55 = [ -1.000000000000000000 ,
   0.074473549049814902 ,
   0.841275918514351351 ,
   0.967220696833122062 ,
   0.992719273731571206 ,
   0.998290424350848582 ,
   0.999574222525855927 ,
   0.999887088636829069 ,
   0.999968196562273426 ,
   0.999990569599544132 ,
   0.999997091166958785 ,
   0.999999077372216605 ,
   0.999999701860501689 ,
   0.999999902501515270 ,
   0.999999967876856855 ,
   0.999999989367565623 ,
   0.999999996470912755 ,
   0.999999998826649805 ,
   0.999999999609486379 ,
   0.999999999869950029 ,
   0.999999999956674879 ,
   0.999999999985563881 ,
   0.999999999995189737 ,
   0.999999999998397615 ,
   0.999999999999466760 ,
   0.999999999999823030 ,
   0.999999999999941824 ,
   0.999999999999981459 ,
   0.999999999999994671 ,
   0.999999999999999112 ,
   1.000000000000000666 ,
   1.000000000000001110 ,
   1.000000000000001332 ,
   1.000000000000001332 ,
   1.000000000000001332]

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, A11, label='A11')
ax.plot(x, A22, label='A22')
ax.plot(x, A33, label='A33')
ax.plot(x, A44, label='A44')
ax.plot(x, A55, label='A55')
ax.grid()
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.set_xlabel('迭代次数', fontsize=15)
ax.set_title('矩阵对角元素随迭代次数的变化', fontsize=15)
ax.legend(fontsize=15)
plt.savefig('Aii.png')

# %%
# l1 : v0 = [1, 2, 3, 4, 5]

l1 = [-0.89090909090909087      ,
   4.7308792823447545      ,
   4.1385933369315220      ,
   4.2141232599660716      ,
   4.4077647128158493      ,
   4.5927750028859240      ,
   4.7346889217012746      ,
   4.8327123985504326      ,
   4.8965875592354582      ,
   4.9368310031838716      ,
   4.9616888896951581      ,
   4.9768645264633200      ,
   4.9860648560898930      ,
   4.9916194602699830      ,
   4.9949646588386445      ,
   4.9969762659538004      ,
   4.9981848483203377      ,
   4.9989105807904739      ,
   4.9993462302884710      ,
   4.9996076956189066      ,
   4.9997646020502424      ,
   4.9998587557141985      ,
   4.9999152514427037      ,
   4.9999491501507105      ,
   4.9999694898330542      ,
   4.9999816938071762      ,
   4.9999890162509484      ,
   4.9999934097385585      ,
   4.9999960458388113      ,
   4.9999976275017319      ,
   4.9999985765004800      ,
   4.9999991459000865      ,
   4.9999994875399780      ,
   4.9999996925239616      ,
   4.9999998155143670      ,
   4.9999998893086142      ,
   4.9999999335851673      ,
   4.9999999601510963      ,
   4.9999999760906588            ]

# l2 : v0 = [-1.00000004e+00,  3.33333333e-01,  1.00000000e+00, -4.21368997e-08, -9.99999958e-01]

l2 = [4.9999998839161215      ,
   4.9999998975941935      ,
   4.9999999320054176      ,
   4.9999999578930341      ,
   4.9999999744737771      ,
   4.9999999846318586       ]

#l3 : v0 = [1, 0, 0, -2, -1]

l3 = [    1.0000000000000000      ,
   5.9925925925925929      ,
   5.1664949515763432      ,
   5.0322518391576532      ,
   5.0064100121536637      ,
   5.0012803999983326      ,
   5.0002560159960350      ,
   5.0000512006398088      ,
   5.0000102400255910      ,
   5.0000020480010257      ,
   5.0000004096000437      ,
   5.0000000819200023      ,
   5.0000000163839999      ,
   5.0000000032768046      ]

print(l1[-1], l3[-1], l2[-1])
# Out:
# 4.999999976090659 5.000000003276805 4.999999984631859

# %%
fig, ax = plt.subplots(figsize=(12, 8))
# ax.plot(np.arange(1, len(l1) + 1), l1, label='1')
# ax.plot(np.arange(2, len(l2) + 1), l2[1:], label='2')
# ax.plot(np.arange(1, len(l3) + 1), l3, label='3')
ax.bar(['(1)', '(2)', '(3)'], [len(l1), len(l3), len(l2)], width = 0.5)
ax.grid()
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.set_xlabel('初始向量类型', fontsize=15)
ax.set_ylabel('迭代次数', fontsize=15)
ax.set_title('不同初始向量的迭代次数', fontsize=15)
# ax.legend(fontsize=15)
plt.show()
plt.savefig('cishu.png')

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(111)
line1, = ax1.plot(["1", "2", "3"], [l1[-1], l3[-1], l2[-1]], 'r', lw=2, label='气温', zorder=3)
scatter1 = ax1.scatter(["1", "2", "3"], [l1[-1], l3[-1], l2[-1]], s=20, c='r', marker='o', zorder=4)
plt.ylim(4.999999, 5.0000001)
ax2=ax1.twinx()
bar1 = ax2.bar(["1", "2", "3"], [len(l1), len(l3), len(l2)], label='降水量', zorder=0)
# plt.legend((line1,bar1), ('气温','降水量'), loc='upper left', frameon=False, framealpha=0.5)
ax1.set_ylabel('迭代次数')
ax2.set_ylabel('特征值')
plt.ylim(0, 50)
plt.title("不同初始向量的迭代次数和特征值")
# for x,y in enumerate(wd_mean): ax1.text(x,y+1.2,'%.1f' %y,ha='center', c='r', zorder=5)
# for x,y in enumerate(js_mean): ax2.text(x,y+5,'%.1f' %y,ha='center', c='b', zorder=5)
ax1.grid()
plt.show()
# plt.savefig('1951年-2021年济南市月平均温度和降水量.png')

# %%
P1 =[-1.0000000421368995,       0.99999999140464846,      -0.50000000000000033,       0.59485530546623855,      -0.47161572052401590,     
  0.33333333333333326,      -0.33333333190077480,       0.25000000000000006,      -0.19614147909967852,       -2.8384279475983716E-002,
   1.0000000000000000,      -0.99999999570232445,        1.0000000000000000,      -0.79742765273311889,        1.0000000000000000,     
  -4.2136899716304952E-008,  -4.2976756853443322E-009,  0.24999999999999931,       -6.4308681672020068E-003,  0.55676855895196764,     
 -0.99999995786310003,        1.0000000000000000,      -0.99999999999999989,        1.0000000000000000,       -1.5283842794759830]

P1 = np.array(P1)
P1 = np.reshape(P1, (5, 5))
print(P1)
rk = np.linalg.det(P1)
print(rk)
# Out:
# [[-1.00000004e+00  9.99999991e-01 -5.00000000e-01  5.94855305e-01
#   -4.71615721e-01]
#  [ 3.33333333e-01 -3.33333332e-01  2.50000000e-01 -1.96141479e-01
#   -2.83842795e-02]
#  [ 1.00000000e+00 -9.99999996e-01  1.00000000e+00 -7.97427653e-01
#    1.00000000e+00]
#  [-4.21368997e-08 -4.29767569e-09  2.50000000e-01 -6.43086817e-03
#    5.56768559e-01]
#  [-9.99999958e-01  1.00000000e+00 -1.00000000e+00  1.00000000e+00
#   -1.52838428e+00]]
# -1.6931275774683063e-09

# %%
P2 = [-1.1666667403490425,        1.0000000000000000,       0.50000000000572886,       0.48527808069792816,      -0.53958201393286720,     
  0.33333333333333331,      -0.28571431084187260,      -0.25000000000095451,      -0.11395856052344593,        3.9582013932867664E-002,
   1.0000000000000000,      -0.85714293252561813,       -1.0000000000000002,      -0.74263904034896389,        1.0000000000000000,     
 -0.16666674034904277,       0.14285706747438218,      -0.24999999999522571,      -0.14340239912758992,       0.42083597213426494,     
 -0.83333325965095684,       0.71428586505123581,        1.0000000000000000,        1.0000000000000000,       -1.4604179860671316,  ]
P2 = np.array(P2)
P2 = np.reshape(P2, (5, 5))
P2[:, 1] = P1[:, 0]
P2[:, 4] = P1[:, 3]
print(P2)
print(np.linalg.det(P2))
# Out:
# [[-1.16666674e+00 -1.00000004e+00  5.00000000e-01  4.85278081e-01
#    5.94855305e-01]
#  [ 3.33333333e-01  3.33333333e-01 -2.50000000e-01 -1.13958561e-01
#   -1.96141479e-01]
#  [ 1.00000000e+00  1.00000000e+00 -1.00000000e+00 -7.42639040e-01
#   -7.97427653e-01]
#  [-1.66666740e-01 -4.21368997e-08 -2.50000000e-01 -1.43402399e-01
#   -6.43086817e-03]
#  [-8.33333260e-01 -9.99999958e-01  1.00000000e+00  1.00000000e+00
#    1.00000000e+00]]
# -0.0015219061875979066

# %%
print(np.matmul(A, P2))
# Out:
# [[-5.83333370e+00 -5.00000021e+00  1.50000000e+00  4.85278081e-01
#    5.94855305e-01]
#  [ 1.66666667e+00  1.66666667e+00 -7.50000000e-01 -1.13958561e-01
#   -1.96141479e-01]
#  [ 5.00000000e+00  5.00000000e+00 -3.00000000e+00 -7.42639040e-01
#   -7.97427653e-01]
#  [-8.33333702e-01 -2.10684499e-07 -7.50000000e-01 -1.43402399e-01
#   -6.43086817e-03]
#  [-4.16666630e+00 -4.99999979e+00  3.00000000e+00  1.00000000e+00
#    1.00000000e+00]]

# %%
P = [-1.0000000421368995,        1.0000000000000000,      -0.50000000000000033,       0.48527808069792816,      -0.47161572052401590,     
  0.33333333333333326,      -0.28571431084187260,       0.25000000000000006,      -0.11395856052344593,       -2.8384279475983716E-002,
   1.0000000000000000,      -0.85714293252561813,        1.0000000000000000,      -0.74263904034896389,        1.0000000000000000,     
  -4.2136899716304952E-008,  0.14285706747438218,       0.24999999999999931,      -0.14340239912758992,       0.55676855895196764,     
 -0.99999995786310003,       0.71428586505123581,      -0.99999999999999989,        1.0000000000000000,       -1.5283842794759830  ]
P = np.array(P)
P = np.reshape(P, (5, 5))
print(np.linalg.det(P))
print(P)
print(np.matmul(A, P))
print(P[:, 0])
# Out:
# 0.003215184028508494
# [[-1.00000004e+00  1.00000000e+00 -5.00000000e-01  4.85278081e-01
#   -4.71615721e-01]
#  [ 3.33333333e-01 -2.85714311e-01  2.50000000e-01 -1.13958561e-01
#   -2.83842795e-02]
#  [ 1.00000000e+00 -8.57142933e-01  1.00000000e+00 -7.42639040e-01
#    1.00000000e+00]
#  [-4.21368997e-08  1.42857067e-01  2.50000000e-01 -1.43402399e-01
#    5.56768559e-01]
#  [-9.99999958e-01  7.14285865e-01 -1.00000000e+00  1.00000000e+00
#   -1.52838428e+00]]
# [[-5.00000021e+00  5.00000000e+00 -1.50000000e+00  4.85278081e-01
#   -4.71615721e-01]
#  [ 1.66666667e+00 -1.42857155e+00  7.50000000e-01 -1.13958561e-01
#   -2.83842795e-02]
#  [ 5.00000000e+00 -4.28571466e+00  3.00000000e+00 -7.42639040e-01
#    1.00000000e+00]
#  [-2.10684499e-07  7.14285337e-01  7.50000000e-01 -1.43402399e-01
#    5.56768559e-01]
#  [-4.99999979e+00  3.57142933e+00 -3.00000000e+00  1.00000000e+00
#   -1.52838428e+00]]
# [-1.00000004e+00  3.33333333e-01  1.00000000e+00 -4.21368997e-08
# ...

# %%
# [-1.00000004e+00,  3.33333333e-01,  1.00000000e+00, -4.21368997e-08, -9.99999958e-01]
