# %%
from sympy import *

def lag_weights_roots(n):
    x = Symbol('x')
    roots = Poly(laguerre(n, x)).all_roots()
    x_i = [rt.evalf(20) for rt in roots]
    w_i = [(rt/((n+1)*laguerre(n+1, rt))**2).evalf(20) for rt in roots]
    return x_i, w_i

# print(lag_weights_roots(5))

# %%
for i in range(39, 101):
    file_path = './nodes/'
    if i < 10:
        file_name = 'data0' + str(i) + '.txt'
    else:
        file_name = 'data' + str(i) + '.txt'

    with open(file_path + file_name, 'w') as f:
        f.write(str(lag_weights_roots(i)[0]) + '\n')
        f.write(str(lag_weights_roots(i)[1]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _get_complexes(cls, factors, use_cache)
#     462                     raise KeyError
# --> 463                 c = _complexes_cache[currentfactor]
#     464                 complexes.extend([(i, currentfactor, k) for i in c])
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in __getitem__(self, k)
#      89             k = PurePoly(k, expand=False)
# ---> 90         return self._dict[k]
#      91
#
# KeyError: PurePoly(x**79 - 6241*x**78 + 18985122*x**77 - 37520929446*x**76 + 54180222120024*x**75 - 60952749885027000*x**74 + 55629543061734642000*x**73 - 42349976425140558174000*x**72 + 27442784723491081696752000*x**71 - 15371008643457615870369648000*x**70 + 7531794235294231776481127520000*x**69 - 3259897486748712498893331647520000*x**68 + 1256147164893837216240230461511040000*x**67 - 433757278708341174130953426286389120000*x**66 + 134960479003823868179602366064536500480000*x**65 - 38013868252743722870587999774844447635200000*x**64 + 9731550272702393054870527942360178594611200000*x**63 - 2272030766609164590281242670778091108353638400000*x**62 + 485204792602534926946727601470610123361743667200000*x**61 - 95023528067054340166777547635375803633107799244800000*x**60 + 17104235052069781230019958574367644653959403864064000000*x**59 - 2835230581726424212461879799874941478115842135752704000000*x**58 + 433532530769440502305534711217241051471895133848731648000000*x**57 - 61241182281300530086551403336731138097051621298892570624000000*x**56 + 8002181151423269264642716702666202044681411849721962561536000000*x**55 - 968263919322215581021768721022610447406450833816357469945856000000*x**54 + 108594522643983870548441445788535848639892716592634553167773696000000*x**53 - 11297852374331507124836000785925822178868838552174461475862085632000000*x**52 + 1091049743578299830912733790183693684702190694467133708240395698176000000*x**51 - 97855875277488202076000709940268526686565448148586716383905834860544000000*x**50 + 8154656273124016839666725828355710557213787345715559698658819571712000000000*x**49 - 631591281024863368775477700447808420899042045711711575370316961021952000000000*x**48 + 45474572233790162551834394432242206304731027291243233426662821193580544000000000*x**47 - 3044040304983105123545520524267364658398510281404736443621156727776346112000000000*x**46 + 189446743686595601218303571451463047563860228101541832785363753999257305088000000000*x**45 - 10960847313295888356201849491120362037623341768732063182581760052814172651520000000000*x**44 + 589450011070578884933521683744695025134410824007368731152174651729117729259520000000000*x**43 - 29456569472148658330867070087674083823608800367287156321631646785057802200023040000000000*x**42 + 1367404961812374560411829253543607470127524311786698519772584866548472712653701120000000000*x**41 - 58938660020682093232109871159148824545753035079831800300967055401743144358227476480000000000*x**40 + 2357546400827283729284394846365952981830121403193272012038682216069725774329099059200000000000*x**39 - 87459221357519476883940599056649133789356454981877237324654528064440314701330723635200000000000*x**38 + 3006931324768050586200243453280984504567398118900731683257169964882186057826703926886400000000000*x**37 - 95732301944359564011817053198643436901227163366862829636722457719156109608482736649011200000000000*x**36 + 2819751439088408976348065930578224868727054630078505163845279663727870864831673334025420800000000000*x**35 - 76759900286295577689475128110185010315347598263248196126899279734814262431528885204025344000000000000*x**34 + 1929009668064297561065940175986388520098735295485106841797729725509680160235812854257680384000000000000*x**33 - 44695564436638724340442741524450576561436653974112369164206971725107270095676599963544977408000000000000*x**32 + 953505374648292785929445152521612299977315284781063875503082063468955095374434132555626184704000000000000*x**31 - 18700380919122640148534628399454477964861224258665354782825752305993180543976146967060342112256000000000000*x**30 + 336606856544207522673623311190180603367502036655976386090863541507877249791570645407086158020608000000000000*x**29 - 5550713065758402481735631464920429165334690447601492954949338008002446413229625740928616841084928000000000000*x**28 + 83687673914511298955398751317261855108123025209991739936159249966806115153308203478616069296357376000000000000*x**27 - 11511002695033723950657677303827149504494657618506411021407564759585218480521071761492663116423495 ...
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_342009/1656313411.py in <module>
#       7
#       8     with open(file_path + file_name, 'w') as f:
# ----> 9         f.write(str(lag_weights_roots(i)[0]) + '\n')
#      10         f.write(str(lag_weights_roots(i)[1]))
#      11
#
# /tmp/ipykernel_342009/2324121271.py in lag_weights_roots(n)
#       3 def lag_weights_roots(n):
#       4     x = Symbol('x')
# ----> 5     roots = Poly(laguerre(n, x)).all_roots()
#       6     x_i = [rt.evalf(20) for rt in roots]
#       7     w_i = [(rt/((n+1)*laguerre(n+1, rt))**2).evalf(20) for rt in roots]
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/polytools.py in all_roots(f, multiple, radicals)
#    3615
#    3616         """
# -> 3617         roots = sympy.polys.rootoftools.CRootOf.all_roots(f, radicals=radicals)
#    3618
#    3619         if multiple:
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in all_roots(cls, poly, radicals)
#     408     def all_roots(cls, poly, radicals=True):
#     409         """Get real and complex roots of a polynomial. """
# --> 410         return cls._get_roots("_all_roots", poly, radicals)
#     411
#     412     @classmethod
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _get_roots(cls, method, poly, radicals)
#     751         roots = []
#     752
# --> 753         for root in getattr(cls, method)(poly):
#     754             roots.append(coeff*cls._postprocess_root(root, radicals))
#     755         return roots
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _all_roots(cls, poly, use_cache)
#     679             roots.append(cls._reals_index(reals, index))
#     680
# --> 681         complexes = cls._get_complexes(factors, use_cache=use_cache)
#     682         complexes_count = cls._count_roots(complexes)
#     683
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _get_complexes(cls, factors, use_cache)
#     464                 complexes.extend([(i, currentfactor, k) for i in c])
#     465             except KeyError:
# --> 466                 complex_part = cls._get_complexes_sqf(currentfactor, use_cache)
#     467                 new = [(root, currentfactor, k) for root in complex_part]
#     468                 complexes.extend(new)
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _get_complexes_sqf(cls, currentfactor, use_cache)
#     429         else:
#     430             _complexes_cache[currentfactor] = complex_part = \
# --> 431                 dup_isolate_complex_roots_sqf(
#     432                 currentfactor.rep.rep, currentfactor.rep.dom, blackbox=True)
#     433         return complex_part
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootisolation.py in dup_isolate_complex_roots_sqf(f, K, eps, inf, sup, blackbox)
#    1555
#    1556     I_L1 = dup_isolate_real_roots_list(S_L1, F, inf=u, sup=s, fast=True, strict=True, basis=True)
# -> 1557     I_L2 = dup_isolate_real_roots_list(S_L2, F, inf=v, sup=t, fast=True, strict=True, basis=True)
#    1558     I_L3 = dup_isolate_real_roots_list(S_L3, F, inf=u, sup=s, fast=True, strict=True, basis=True)
#    1559     I_L4 = dup_isolate_real_roots_list(S_L4, F, inf=v, sup=t, fast=True, strict=True, basis=True)
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/rootisolation.py in dup_isolate_real_roots_list(polys, K, eps, inf, sup, strict, basis, fast)
#     589             zero_indices[i] = j
#     590
# --> 591         for f, k in dup_factor_list(p, K)[1]:
#     592             f = tuple(f)
#     593
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_factor_list(f, K0)
#    1328
#    1329         if K.is_ZZ:
# -> 1330             coeff, factors = dup_zz_factor(f, K)
#    1331         elif K.is_Poly:
#    1332             f, u = dmp_inject(f, 0, K)
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_factor(f, K)
#     674
#     675     if H is None:
# --> 676         H = dup_zz_zassenhaus(g, K)
#     677
#     678     factors = dup_trial_division(f, H, K)
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_zassenhaus(f, K)
#     351     modular = [gf_to_int_poly(ff, p) for ff in fsqf]
#     352
# --> 353     g = dup_zz_hensel_lift(p, f, modular, l, K)
#     354
#     355     sorted_T = range(len(g))
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_hensel_lift(p, f, f_list, l, K)
#     301
#     302     for _ in range(1, d + 1):
# --> 303         (g, h, s, t), m = dup_zz_hensel_step(m, f, g, h, s, t, K), m**2
#     304
#     305     return dup_zz_hensel_lift(p, g, f_list[:k], l, K) \
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_hensel_step(m, f, g, h, s, t, K)
#     237     b = dup_trunc(dup_sub(u, [K.one], K), M, K)
#     238
# --> 239     c, d = dup_div(dup_mul(s, b, K), H, K)
#     240
#     241     c = dup_trunc(c, M, K)
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/densearith.py in dup_div(f, g, K)
#    1534         return dup_ff_div(f, g, K)
#    1535     else:
# -> 1536         return dup_rr_div(f, g, K)
#    1537
#    1538
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/densearith.py in dup_rr_div(f, g, K)
#    1342
#    1343         q = dup_add_term(q, c, j, K)
# -> 1344         h = dup_mul_term(g, c, j, K)
#    1345         r = dup_sub(r, h, K)
#    1346
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/densearith.py in dup_mul_term(f, c, i, K)
#     155         return []
#     156     else:
# --> 157         return [ cf * c for cf in f ] + [K.zero]*i
#     158
#     159
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     155         return []
#     156     else:
# --> 157         return [ cf * c for cf in f ] + [K.zero]*i
#     158
#     159
#
# KeyboardInterrupt:
